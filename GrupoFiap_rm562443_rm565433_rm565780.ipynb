# %% [markdown]
# <a href="https://colab.research.google.com/github/clebercco/Fiap_Fase6_Cleber_Arthur_Rodrigo/blob/main/GrupoFiap_rm562443_rm565433_rm565780.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Passo 1: Importar bibliotecas e montar o Google Drive
import os
import shutil
from google.colab import drive
import yaml
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Tentar montar o Google Drive
try:
    drive.mount('/content/drive', force_remount=True)
    print("Google Drive montado com sucesso!")
except Exception as e:
    print(f"Erro ao montar Google Drive: {e}")
    raise SystemExit("Por favor, verifique a conexão com o Google Drive e tente novamente.")

# Resetar o diretório de trabalho
os.chdir('/content')
print(f"Diretório de trabalho atual: {os.getcwd()}")

# Função para verificar diretórios
def check_directory(path, name):
    if os.path.exists(path):
        print(f"{name} encontrado: {path}")
        print(f"Conteúdo de {name}:")
        # !ls -l {path}
        return True
    else:
        print(f"ERRO: {name} não encontrado em {path}")
        return False

# Definir diretórios
base_dir = "/content/drive/MyDrive/Fiap/Fase6"
train_image_dir = f"{base_dir}/train/Imagens"
train_label_dir = f"{base_dir}/train/labels"
val_image_dir = f"{base_dir}/val/Imagens"
val_label_dir = f"{base_dir}/val/labels"
test_image_dir = f"{base_dir}/test/Imagens"
subset_train_image_dir = "/content/test_dataset/train/Imagens"
subset_train_label_dir = "/content/test_dataset/train/labels"

# Verificar diretórios
print("\nVerificando diretórios...")
base_dir_exists = check_directory(base_dir, "Diretório base (Fiap/Fase6)")
if not base_dir_exists:
    print("Possíveis caminhos alternativos:")
    # !ls -R /content/drive/MyDrive
    print("\nVerificando Shared drives:")
    # !ls -R /content/drive/Shared\ drives
    raise SystemExit("Por favor, verifique o caminho do diretório 'Fiap/Fase6' no Google Drive e atualize o script.")

check_directory(train_image_dir, "Diretório de imagens de treinamento")
check_directory(train_label_dir, "Diretório de rótulos de treinamento")
check_directory(val_image_dir, "Diretório de imagens de validação")
check_directory(val_label_dir, "Diretório de rótulos de validação")
check_directory(test_image_dir, "Diretório de imagens de teste")

# Função para criar arquivos de rótulo vazios (para YOLOv5)
def create_missing_labels(image_dir, label_dir):
    os.makedirs(label_dir, exist_ok=True)
    image_extensions = (".jpg", ".jpeg", ".png")
    missing_labels = []
    for image_file in os.listdir(image_dir):
        if image_file.endswith(image_extensions):
            label_file = os.path.splitext(image_file)[0] + ".txt"
            label_path = os.path.join(label_dir, label_file)
            if not os.path.exists(label_path):
                print(f"Criando arquivo de rótulo vazio para {image_file}")
                with open(label_path, "w") as f:
                    pass
                missing_labels.append(image_file)
    return missing_labels

# Função para validar arquivos de rótulo (para YOLOv5)
def validate_labels(label_dir, num_classes=2):
    empty_labels = []
    invalid_labels = []
    valid_labels = []
    if not os.path.exists(label_dir):
        print(f"ERRO: Diretório de rótulos {label_dir} não existe")
        return empty_labels, invalid_labels, valid_labels
    for label_file in os.listdir(label_dir):
        if label_file.endswith(".txt"):
            label_path = os.path.join(label_dir, label_file)
            with open(label_path, "r") as f:
                content = f.read().strip()
                if not content:
                    empty_labels.append(label_file)
                    continue
                lines = content.splitlines()
                is_valid = True
                for line in lines:
                    parts = line.split()
                    if len(parts) != 5:
                        invalid_labels.append(f"{label_file}: {line} (Formato inválido, esperado 5 valores)")
                        is_valid = False
                    else:
                        try:
                            class_id, x, y, w, h = map(float, parts)
                            if not (0 <= class_id < num_classes and 0 <= x <= 1 and 0 <= y <= 1 and 0 <= w <= 1 and 0 <= h <= 1):
                                invalid_labels.append(f"{label_file}: {line} (Valores fora do intervalo)")
                                is_valid = False
                        except ValueError:
                            invalid_labels.append(f"{label_file}: {line} (Valores não numéricos)")
                            is_valid = False
                if is_valid:
                    valid_labels.append(label_file)
    return empty_labels, invalid_labels, valid_labels

# Função para criar um dataset de teste com anotações válidas (para YOLOv5)
def create_test_subset(train_image_dir, train_label_dir, subset_image_dir, subset_label_dir, num_images=5):
    os.makedirs(subset_image_dir, exist_ok=True)
    os.makedirs(subset_label_dir, exist_ok=True)
    if not os.path.exists(train_image_dir):
        print(f"ERRO: Diretório de imagens {train_image_dir} não existe")
        return
    image_files = [f for f in os.listdir(train_image_dir) if f.endswith((".jpg", ".jpeg", ".png"))]
    if not image_files:
        print(f"ERRO: Nenhuma imagem encontrada em {train_image_dir}")
        return
    selected_images = image_files[:min(num_images, len(image_files))]
    for img in selected_images:
        shutil.copy(os.path.join(train_image_dir, img), os.path.join(subset_image_dir, img))
        label_file = os.path.splitext(img)[0] + ".txt"
        subset_label_path = os.path.join(subset_label_dir, label_file)
        with open(subset_label_path, "w") as f:
            f.write("0 0.5 0.5 0.2 0.3\n")  # MOTO: class_id=0, center at (50%, 50%), width=20%, height=30%
        print(f"Criado rótulo de amostra para {img}")

# Criar arquivos de rótulo faltantes (para YOLOv5)
try:
    missing_train_labels = create_missing_labels(train_image_dir, train_label_dir)
    missing_val_labels = create_missing_labels(val_image_dir, val_label_dir)
    print(f"\nImagens sem rótulos (treinamento): {missing_train_labels}")
    print(f"Imagens sem rótulos (validação): {missing_val_labels}")
except FileNotFoundError as e:
    print(f"Erro ao criar rótulos faltantes: {e}")
    raise SystemExit("Por favor, corrija o caminho do diretório e tente novamente.")

# Validar arquivos de rótulo (para YOLOv5)
print("\nValidando rótulos de treinamento...")
empty_train_labels, invalid_train_labels, valid_train_labels = validate_labels(train_label_dir)
print(f"Rótulos vazios (treinamento): {len(empty_train_labels)} ({empty_train_labels})")
print(f"Rótulos inválidos (treinamento): {invalid_train_labels}")
print(f"Rótulos válidos (treinamento): {len(valid_train_labels)} ({valid_train_labels})")
print("\nValidando rótulos de validação...")
empty_val_labels, invalid_val_labels, valid_val_labels = validate_labels(val_label_dir)
print(f"Rótulos vazios (validação): {len(empty_val_labels)} ({empty_val_labels})")
print(f"Rótulos inválidos (validação): {invalid_val_labels}")
print(f"Rótulos válidos (validação): {len(valid_val_labels)} ({valid_val_labels})")

# Criar dataset de teste com anotações válidas (para YOLOv5)
print("\nCriando dataset de teste com anotações válidas...")
create_test_subset(train_image_dir, train_label_dir, subset_train_image_dir, subset_train_label_dir)

# Remover arquivo de cache
cache_path = f"{train_image_dir}.cache"
if os.path.exists(cache_path):
    print(f"Removendo cache: {cache_path}")
    os.remove(cache_path)

# Exibir estrutura do dataset
print("\nEstrutura do dataset original:")
# !ls -R {base_dir}
print("\nEstrutura do dataset de teste:")
# !ls -R /content/test_dataset

# Passo 2: Configurar a CNN (para alternativa ou complemento ao YOLOv5)
print("\nConfigurando modelo CNN...")
hand_model = Sequential()
hand_model.add(layers.Rescaling(1./255, input_shape=(150, 150, 3)))
hand_model.add(layers.Conv2D(16, kernel_size=10, activation="relu"))
hand_model.add(layers.MaxPooling2D(pool_size=(2, 2)))
hand_model.add(layers.Conv2D(32, kernel_size=5, activation="relu"))
hand_model.add(layers.MaxPooling2D(pool_size=(2, 2)))
hand_model.add(layers.Conv2D(64, kernel_size=3, activation="relu"))
hand_model.add(layers.MaxPooling2D(pool_size=(2, 2)))
hand_model.add(layers.Flatten())
hand_model.add(layers.Dense(128, activation="relu"))
hand_model.add(layers.Dense(2, activation="softmax"))  # 2 classes: MOTO, CACHORRO

hand_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
hand_model.summary()

# Carregar dados para a CNN
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    f"{base_dir}/train",
    target_size=(150, 150),
    batch_size=16,
    class_mode="categorical"
)

val_generator = val_datagen.flow_from_directory(
    f"{base_dir}/val",
    target_size=(150, 150),
    batch_size=16,
    class_mode="categorical"
)

# Treinar a CNN
print("\nTreinando a CNN...")
history = hand_model.fit(
    train_generator,
    epochs=30,
    validation_data=val_generator
)

# Passo 3: Instalar YOLOv5
if os.path.exists("/content/yolov5"):
    shutil.rmtree("/content/yolov5")
# !git clone https://github.com/ultralytics/yolov5 /content/yolov5
os.chdir('/content/yolov5')
print(f"Diretório de trabalho atual: {os.getcwd()}")

# Instalar dependências
# !pip install -r requirements.txt
# !pip install albumentations==1.3.1

# Instalar PyTorch CPU
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu --index-url https://download.pytorch.org/whl/cpu

# Passo 4: Desativar W&B
os.environ['WANDB_MODE'] = 'disabled'

# Passo 5: Criar arquivo data.yaml (para YOLOv5)
data = {
    'train': subset_train_image_dir,  # Usar subset temporário
    'val': val_image_dir,
    'test': test_image_dir,
    'nc': 2,
    'names': ['MOTO', 'CACHORRO']
}

with open('data.yaml', 'w') as f:
    yaml.dump(data, f)
print("Arquivo data.yaml criado com sucesso!")

# Passo 6: Treinamento YOLOv5
# Simulação 1: 30 épocas
# !python train.py --img 640 --batch 16 --epochs 30 --data data.yaml --weights yolov5s.pt --cache --project runs/train --name exp_30epochs

# Simulação 2: 60 épocas
# !python train.py --img 640 --batch 16 --epochs 60 --data data.yaml --weights yolov5s.pt --cache --project runs/train --name exp_60epochs

# Passo 7: Validação YOLOv5
# !python val.py --weights runs/train/exp_30epochs/weights/best.pt --data data.yaml --img 640 --task val
# !python val.py --weights runs/train/exp_60epochs/weights/best.pt --data data.yaml --img 640 --task val

# Passo 8: Teste (Inferência) YOLOv5
# !python detect.py --weights runs/train/exp_30epochs/weights/best.pt --img 640 --conf 0.4 --source {test_image_dir} --data data.yaml --save-txt --save-conf --project runs/detect --name exp_30epochs
# !python detect.py --weights runs/train/exp_60epochs/weights/best.pt --img 640 --conf 0.4 --source {test_image_dir} --data data.yaml --save-txt --save-conf --project runs/detect --name exp_60epochs

# Passo 9: Exibir resultados
# !ls -R runs/detect/exp*
# Out:
# Mounted at /content/drive
# Google Drive montado com sucesso!
# Diretório de trabalho atual: /content
#
# Verificando diretórios...
# Diretório base (Fiap/Fase6) encontrado: /content/drive/MyDrive/Fiap/Fase6
# Conteúdo de Diretório base (Fiap/Fase6):
# total 12
# drwx------ 2 root root 4096 Oct 16 21:07 test
# drwx------ 2 root root 4096 Oct 16 22:26 train
# drwx------ 2 root root 4096 Oct 16 21:07 val
# Diretório de imagens de treinamento encontrado: /content/drive/MyDrive/Fiap/Fase6/train/Imagens
# Conteúdo de Diretório de imagens de treinamento:
# total 195200
# -rw------- 1 root root 1846296 Oct 16 21:14 alan-king-KZv7w34tluA-unsplash.jpg
# -rw------- 1 root root  514924 Oct 16 21:14 alvan-nee-1VgfQdCuX-4-unsplash.jpg
# -rw------- 1 root root 1951781 Oct 16 21:14 alvan-nee-brFsZ7qszSY-unsplash.jpg
# -rw------- 1 root root 1855662 Oct 16 21:14 alvan-nee-eoqnr8ikwFE-unsplash.jpg
# -rw------- 1 root root 1705114 Oct 16 21:14 alvan-nee-T-0EW-SEbsE-unsplash.jpg
# -rw------- 1 root root 1730069 Oct 16 21:14 andrew-pons-cLHPacdtpSY-unsplash.jpg
# -rw------- 1 root root 3791269 Oct 16 21:14 angel-luciano-LATYeZyw88c-unsplash.jpg
# -rw------- 1 root root  834388 Oct 16 21:14 anoir-chafik-2_3c4dIFYFU-unsplash.jpg
# -rw------- 1 root root 2168035 Oct 16 21:14 bastian-scham-vKl5b0sQIbE-unsplash.jpg
# -rw------- 1 root root 1600903 Oct 16 21:14 brooke-cagle-Ntm4C2lCWxQ-unsplash.jpg
# -rw------- 1 root root 5641336 Oct 16 21:14 caleb-fisher-pgUbpDLJh3E-unsplash.jpg
# -rw------- 1 root root  422555 Oct 16 21:14 celine-sayuri-tagami-2s6ORaJY6gI-unsplash.jpg
# -rw------- 1 root root 1476577 Oct 16 21:14 charlesdeluvio-DziZIYOGAHc-unsplash.jpg
# -rw------- 1 root root 1648370 Oct 16 21:14 charlesdeluvio-K4mSJ7kc0As-unsplash.jpg
# -rw------- 1 root root 2842797 Oct 16 21:14 charlesdeluvio-zqhe4qjVTJI-unsplash.jpg
# -rw------- 1 root root 5946284 Oct 16 21:14 christopher-burns-ZrfnOyYUfi4-unsplash.jpg
# -rw------- 1 root root 2294896 Oct 16 21:14 cok-wisnu-iwuaqJBQTO0-unsplash.jpg
# -rw------- 1 root root 4212322 Oct 16 21:14 cristian-castillo-73pyV0JJOmE-unsplash.jpg
# -rw------- 1 root root 2424254 Oct 16 21:14 daniel-thurler-YRGsG4oiNIg-unsplash.jpg
# -rw------- 1 root root  385672 Oct 16 21:14 fatty-corgi-1QsQRkxnU6I-unsplash.jpg
# -rw------- 1 root root 1067747 Oct 16 21:14 flouffy--dMO9Dm-gkU-unsplash.jpg
# -rw------- 1 root root 1545400 Oct 16 21:14 fredrik-ohlander-tGBRQw52Thw-unsplash.jpg
# -rw------- 1 root root 1814953 Oct 16 21:14 glen-alejandro-EQ7vori1wJU-unsplash.jpg
# -rw------- 1 root root 8478862 Oct 16 21:14 harley-davidson-2S4FDh3AtGw-unsplash.jpg
# -rw------- 1 root root 2563151 Oct 16 21:14 harley-davidson-4ixHdlcROPI-unsplash.jpg
# -rw------- 1 root root 4677959 Oct 16 21:14 harley-davidson-52UeZUkp3Hs-unsplash.jpg
# -rw------- 1 root root 7939001 Oct 16 21:14 harley-davidson-HYjJ1_AZnqw-unsplash.jpg
# -rw------- 1 root root 4845578 Oct 16 21:14 harley-davidson-kdGstD3te3M-unsplash.jpg
# -rw------- 1 root root 8498010 Oct 16 21:14 harley-davidson-MVx3Y17umaE-unsplash.jpg
# -rw------- 1 root root 4041255 Oct 16 21:14 harley-davidson-QD6GvrDFPAA-unsplash.jpg
# -rw------- 1 root root 8395279 Oct 16 21:14 harley-davidson-xAHtaYIHlPI-unsplash.jpg
# -rw------- 1 root root 4255790 Oct 16 21:14 harley-davidson-XnhmpwEbv5I-unsplash.jpg
# -rw------- 1 root root 4184831 Oct 16 21:14 harley-davidson-YsMg1pJqqKk-unsplash.jpg
# -rw------- 1 root root 8302949 Oct 16 21:14 james-barker-v3-zcCWMjgM-unsplash.jpg
# -rw------- 1 root root 2673534 Oct 16 21:14 jamie-street-uNNCs5kL70Q-unsplash.jpg
# -rw------- 1 root root 5240320 Oct 16 21:14 jamie-street-UtrE5DcgEyg-unsplash.jpg
# -rw------- 1 root root  930841 Oct 16 21:14 ja-san-miguel-_-QQuvAwQ-0-unsplash.jpg
# -rw------- 1 root root 2169158 Oct 16 21:14 joe-caione-qO-PIF84Vxg-unsplash.jpg
# -rw------- 1 root root 1429729 Oct 16 21:14 john-cameron-ShLDezSsZJk-unsplash.jpg
# -rw------- 1 root root 2197140 Oct 16 21:14 josh-marshall-7waHOTcvcT4-unsplash.jpg
# -rw------- 1 root root  559250 Oct 16 21:14 justin-veenema-NH1d0xX6Ldk-unsplash.jpg
# -rw------- 1 root root 1980399 Oct 16 21:14 karsten-winegeart-5PVXkqt2s9k-unsplash.jpg
# -rw------- 1 root root 1077826 Oct 16 21:14 karsten-winegeart-NE0XGVKTmcA-unsplash.jpg
# -rw------- 1 root root  876958 Oct 16 21:14 karsten-winegeart-nwe2qgAhT4k-unsplash.jpg
# -rw------- 1 root root 1675271 Oct 16 21:14 karsten-winegeart-oU6KZTXhuvk-unsplash.jpg
# -rw------- 1 root root 4357264 Oct 16 21:14 kirill-petropavlov-AYF1NkngJxs-unsplash.jpg
# -rw------- 1 root root 3304831 Oct 16 21:14 kristian-angelo-KW-jwdSgOw4-unsplash.jpg
# -rw------- 1 root root 2328496 Oct 16 21:14 leandro-vergara-AMZTnhB08ig-unsplash.jpg
# -rw------- 1 root root 5566818 Oct 16 21:14 lloyd-dirks-4spc49IbnpQ-unsplash.jpg
# -rw------- 1 root root  849539 Oct 16 21:14 lucas-t-wb6dyvkqpyo-unsplash.jpg
# -rw------- 1 root root 2134823 Oct 16 21:14 max-itin-7GeprSfVqLQ-unsplash.jpg
# -rw------- 1 root root 1244060 Oct 16 21:14 nick-mercer-v0smCPnCisc-unsplash.jpg
# -rw------- 1 root root 2795521 Oct 16 21:14 oscar-sutton-yihlaRCCvd4-unsplash.jpg
# -rw------- 1 root root 4742425 Oct 16 21:14 oxana-melis-BuAuuEI2ubM-unsplash.jpg
# -rw------- 1 root root 3683570 Oct 16 21:14 raul-varzar-o16vpvZaLk4-unsplash.jpg
# -rw------- 1 root root 1570377 Oct 16 21:14 ryan-walton-AbNO2iejoXA-unsplash.jpg
# -rw------- 1 root root 5400379 Oct 16 21:14 taylor-kopel-WX4i1Jq_o0Y-unsplash.jpg
# -rw------- 1 root root 2055923 Oct 16 21:14 thewyzzwguy-Q-UM3WUQxRk-unsplash.jpg
# -rw------- 1 root root 1416959 Oct 16 21:14 tim-meyer-2LTMNCN4nEg-unsplash.jpg
# -rw------- 1 root root 4146547 Oct 16 21:14 tobias-reich-4uH2e12CMLI-unsplash.jpg
# -rw------- 1 root root 4976014 Oct 16 21:14 tobias-reich-cTKDRoqAEG0-unsplash.jpg
# -rw------- 1 root root 1694927 Oct 16 21:14 victor-g-N04FIfHhv_k-unsplash.jpg
# -rw------- 1 root root 3346741 Oct 16 21:14 yulian-as-gpvgmCBc_QE-unsplash.jpg
# -rw------- 1 root root 7537489 Oct 16 21:14 zac-wolff-Ptx8G07I6xI-unsplash.jpg
# Diretório de rótulos de treinamento encontrado: /content/drive/MyDrive/Fiap/Fase6/train/labels
# Conteúdo de Diretório de rótulos de treinamento:
# total 32
# -rw------- 1 root root  37 Oct 16 21:31 alan-king-KZv7w34tluA-unsplash.txt
# -rw------- 1 root root  75 Oct 16 21:31 alvan-nee-1VgfQdCuX-4-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 alvan-nee-brFsZ7qszSY-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 alvan-nee-eoqnr8ikwFE-unsplash.txt
# -rw------- 1 root root  75 Oct 16 21:31 alvan-nee-T-0EW-SEbsE-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 andrew-pons-cLHPacdtpSY-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 angel-luciano-LATYeZyw88c-unsplash.txt
# -rw------- 1 root root 113 Oct 16 21:31 anoir-chafik-2_3c4dIFYFU-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 bastian-scham-vKl5b0sQIbE-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 brooke-cagle-Ntm4C2lCWxQ-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 caleb-fisher-pgUbpDLJh3E-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 celine-sayuri-tagami-2s6ORaJY6gI-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31 charlesdeluvio-DziZIYOGAHc-unsplash.txt
# -rw------- 1 root root  37 Oct 16 21:31
# -rw------- 1 root root  981047 Oct 16 21:14 pauline-loroy-U3aF7hgUSrk-unsplash.jpg
# -rw------- 1 root root 4438457 Oct 16 21:14 peri-stojnic-5Vr_RVPfbMI-unsplash.jpg
# Diretório de rótulos de validação encontrado: /content/drive/MyDrive/Fiap/Fase6/val/labels
# Conteúdo de Diretório de rótulos de validação:
# total 4
# -rw------- 1 root root 37 Oct 16 21:37 conor-luddy-HKF3K2RT0KE-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 conor-luddy-kf4KHfDlIIg-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 domino-studio-5RUIYPB5QTY-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 eric-michael-KA9W4k0pOn4-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 karsten-winegeart-Qb7D1xw28Co-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 kieran-white-NKN25UfGfkQ-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 pauline-loroy-U3aF7hgUSrk-unsplash.txt
# -rw------- 1 root root 37 Oct 16 21:37 peri-stojnic-5Vr_RVPfbMI-unsplash.txt
# Diretório de imagens de teste encontrado: /content/drive/MyDrive/Fiap/Fase6/test/Imagens
# Conteúdo de Diretório de imagens de teste:
# total 19152
# -rw------- 1 root root 4221310 Oct 16 21:14 gijs-coolen-wNDuDOqg2jU-unsplash.jpg
# -rw------- 1 root root 3369526 Oct 16 21:14 jane-duursma-eD5eD7OVdMQ-unsplash.jpg
# -rw------- 1 root root 1910497 Oct 16 21:14 majestic-lukas-4dZMVjr99pY-unsplash.jpg
# -rw------- 1 root root 1467522 Oct 16 21:14 nick-wood-Y0u3Pj5giyI-unsplash.jpg
# -rw------- 1 root root 3659663 Oct 16 21:14 ralu-gal-G8cB8hY3yvU-unsplash.jpg
# -rw------- 1 root root 2383212 Oct 16 21:14 richard-brutyo-Sg3XwuEpybU-unsplash.jpg
# -rw------- 1 root root  652751 Oct 16 21:14 t-r-photography-TzjMd7i5WQI-unsplash.jpg
# -rw------- 1 root root 1945353 Oct 16 21:14 victor-g-x5oPmHmY3kQ-unsplash.jpg
#
# Imagens sem rótulos (treinamento): []
# Imagens sem rótulos (validação): []
#
# Validando rótulos de treinamento...
# Rótulos vazios (treinamento): 0 ([])
# Rótulos inválidos (treinamento): []
# Rótulos válidos (treinamento): 64 (['harley-davidson-MVx3Y17umaE-unsplash.txt', 'thewyzzwguy-Q-UM3WUQxRk-unsplash.txt', 'john-cameron-ShLDezSsZJk-unsplash.txt', 'lucas-t-wb6dyvkqpyo-unsplash.txt', 'taylor-kopel-WX4i1Jq_o0Y-unsplash.txt', 'yulian-as-gpvgmCBc_QE-unsplash.txt', 'christopher-burns-ZrfnOyYUfi4-unsplash.txt', 'fredrik-ohlander-tGBRQw52Thw-unsplash.txt', 'caleb-fisher-pgUbpDLJh3E-unsplash.txt', 'alvan-nee-1VgfQdCuX-4-unsplash.txt', 'karsten-winegeart-oU6KZTXhuvk-unsplash.txt', 'james-barker-v3-zcCWMjgM-unsplash.txt', 'nick-mercer-v0smCPnCisc-unsplash.txt', 'brooke-cagle-Ntm4C2lCWxQ-unsplash.txt', 'angel-luciano-LATYeZyw88c-unsplash.txt', 'kirill-petropavlov
# Rótulos válidos (validação): 8 (['conor-luddy-HKF3K2RT0KE-unsplash.txt', 'domino-studio-5RUIYPB5QTY-unsplash.txt', 'pauline-loroy-U3aF7hgUSrk-unsplash.txt', 'conor-luddy-kf4KHfDlIIg-unsplash.txt', 'eric-michael-KA9W4k0pOn4-unsplash.txt', 'kieran-white-NKN25UfGfkQ-unsplash.txt', 'karsten-winegeart-Qb7D1xw28Co-unsplash.txt', 'peri-stojnic-5Vr_RVPfbMI-unsplash.txt'])
#
# Criando dataset de teste com anotações válidas...
# Criado rótulo de amostra para christopher-burns-ZrfnOyYUfi4-unsplash.jpg
# Criado rótulo de amostra para lucas-t-wb6dyvkqpyo-unsplash.jpg
# Criado rótulo de amostra para justin-veenema-NH1d0xX6Ldk-unsplash.jpg
# Criado rótulo de amostra para kirill-petropavlov-AYF1NkngJxs-unsplash.jpg
# Criado rótulo de amostra para lloyd-dirks-4spc49IbnpQ-unsplash.jpg
#
# Estrutura do dataset original:
# /content/drive/MyDrive/Fiap/Fase6:
# test  train  val
#
# /content/drive/MyDrive/Fiap/Fase6/test:
# Imagens
#
# /content/drive/MyDrive/Fiap/Fase6/test/Imagens:
# gijs-coolen-wNDuDOqg2jU-unsplash.jpg
# jane-duursma-eD5eD7OVdMQ-unsplash.jpg
# majestic-lukas-4dZMVjr99pY-unsplash.jpg
# nick-wood-Y0u3Pj5giyI-unsplash.jpg
# ralu-gal-G8cB8hY3yvU-unsplash.jpg
# richard-brutyo-Sg3XwuEpybU-unsplash.jpg
# t-r-photography-TzjMd7i5WQI-unsplash.jpg
# victor-g-x5oPmHmY3kQ-unsplash.jpg
#
# /content/drive/MyDrive/Fiap/Fase6/train:
# Imagens  labels
#
# /content/drive/MyDrive/Fiap/Fase6/train/Imagens:
# alan-king-KZv7w34tluA-unsplash.jpg
# alvan-nee-1VgfQdCuX-4-unsplash.jpg
# alvan-nee-brFsZ7qszSY-unsplash.jpg
# alvan-nee-eoqnr8ikwFE-unsplash.jpg
# alvan-nee-T-0EW-SEbsE-unsplash.jpg
# andrew-pons-cLHPacdtpSY-unsplash.jpg
# angel-luciano-LATYeZyw88c-unsplash.jpg
# anoir-chafik-2_3c4dIFYFU-unsplash.jpg
# bastian-scham-vKl5b0sQIbE-unsplash.jpg
# brooke-cagle-Ntm4C2lCWxQ-unsplash.jpg
# caleb-fisher-pgUbpDLJh3E-unsplash.jpg
# celine-sayuri-tagami-2s6ORaJY6gI-unsplash.jpg
# charlesdeluvio-DziZIYOGAHc-unsplash.jpg
# charlesdeluvio-K4mSJ7kc0As-unsplash.jpg
# charlesdeluvio-zqhe4qjVTJI-unsplash.jpg
# christopher-burns-ZrfnOyYUfi4-unsplash.jpg
# cok-wisnu-iwuaqJBQTO0-unsplash.jpg
# cristian-castillo-73pyV0JJOmE-unsplash.jpg
# daniel-thurler-YRGsG4oiNIg-unsplash.jpg
# fatty-corgi-1QsQRkxnU6I-unsplash.jpg
# anoir-chafik-2_3c4dIFYFU-unsplash.txt
# bastian-scham-vKl5b0sQIbE-unsplash.txt
# brooke-cagle-Ntm4C2lCWxQ-unsplash.txt
# caleb-fisher-pgUbpDLJh3E-unsplash.txt
# celine-sayuri-tagami-2s6ORaJY6gI-unsplash.txt
# charlesdeluvio-DziZIYOGAHc-unsplash.txt
# charlesdeluvio-K4mSJ7kc0As-unsplash.txt
# charlesdeluvio-zqhe4qjVTJI-unsplash.txt
# christopher-burns-ZrfnOyYUfi4-unsplash.txt
# cok-wisnu-iwuaqJBQTO0-unsplash.txt
# cristian-castillo-73pyV0JJOmE-unsplash.txt
# daniel-thurler-YRGsG4oiNIg-unsplash.txt
# fatty-corgi-1QsQRkxnU6I-unsplash.txt
# flouffy--dMO9Dm-gkU-unsplash.txt
# fredrik-ohlander-tGBRQw52Thw-unsplash.txt
# glen-alejandro-EQ7vori1wJU-unsplash.txt
# harley-davidson-2S4FDh3AtGw-unsplash.txt
# harley-davidson-4ixHdlcROPI-unsplash.txt
# harley-davidson-52UeZUkp3Hs-unsplash.txt
# harley-davidson-HYjJ1_AZnqw-unsplash.txt
# harley-davidson-kdGstD3te3M-unsplash.txt
# harley-davidson-MVx3Y17umaE-unsplash.txt
# harley-davidson-QD6GvrDFPAA-unsplash.txt
# harley-davidson-xAHtaYIHlPI-unsplash.txt
# harley-davidson-XnhmpwEbv5I-unsplash.txt
# harley-davidson-YsMg1pJqqKk-unsplash.txt
# james-barker-v3-zcCWMjgM-unsplash.txt
# jamie-street-uNNCs5kL70Q-unsplash.txt
# jamie-street-UtrE5DcgEyg-unsplash.txt
# ja-san-miguel-_-QQuvAwQ-0-unsplash.txt
# joe-caione-qO-PIF84Vxg-unsplash.txt
# john-cameron-ShLDezSsZJk-unsplash.txt
# josh-marshall-7waHOTcvcT4-unsplash.txt
# justin-veenema-NH1d0xX6Ldk-unsplash.txt
# karsten-winegeart-5PVXkqt2s9k-unsplash.txt
# karsten-winegeart-NE0XGVKTmcA-unsplash.txt
# karsten-winegeart-nwe2qgAhT4k-unsplash.txt
# karsten-winegeart-oU6KZTXhuvk-unsplash.txt
# kirill-petropavlov-AYF1NkngJxs-unsplash.txt
# kristian-angelo-KW-jwdSgOw4-unsplash.txt
# leandro-vergara-AMZTnhB08ig-unsplash.txt
# lloyd-dirks-4spc49IbnpQ-unsplash.txt
# lucas-t-wb6dyvkqpyo-unsplash.txt
# max-itin-7GeprSfVqLQ-unsplash.txt
# nick-mercer-v0smCPnCisc-unsplash.txt
# oscar-sutton-yihlaRCCvd4-unsplash.txt
# oxana-melis-BuAuuEI2ubM-unsplash.txt
# raul-varzar-o16vpvZaLk4-unsplash.txt
# ryan-walton-AbNO2iejoXA-unsplash.txt
# taylor-kopel-WX4i1Jq_o0Y-unsplash.txt
# thewyzzwguy-Q-UM3WUQxRk-unsplash.txt
# tim-meyer-2LTMNCN4nEg-unsplash.txt
# tobias-reich-4uH2e12CMLI-unsplash.txt
# tobias-reich-cTKDRoqAEG0-unsplash.txt
# victor-g-N04FIfHhv_k-unsplash.txt
# yulian-as-gpvgmCBc_QE-unsplash.txt
# zac-wolff-Ptx8G07I6xI-unsplash.txt
#
# /content/drive/MyDrive/Fiap/Fase6/val:
# Imagens  labels
#
# /content/drive/MyDrive/Fiap/Fase6/val/Imagens:
# conor-luddy-HKF3K2RT0KE-unsplash.jpg
# conor-luddy-kf4KHfDlIIg-unsplash.jpg
# domino-studio-5RUIYPB5QTY-unsplash.jpg
# eric-michael-KA9W4k0pOn4-unsplash.jpg
# karsten-winegeart-Qb7D1xw28Co-unsplash.jpg
# kieran-white-NKN25UfGfkQ-unsplash.jpg
# pauline-loroy-U3aF7hgUSrk-unsplash.jpg
# peri-stojnic-5Vr_RVPfbMI-unsplash.jpg
#
# /content/drive/MyDrive/Fiap/Fase6/val/labels:
# conor-luddy-HKF3K2RT0KE-unsplash.txt
# conor-luddy-kf4KHfDlIIg-unsplash.txt
# domino-studio-5RUIYPB5QTY-unsplash.txt
# eric-michael-KA9W4k0pOn4-unsplash.txt
# karsten-winegeart-Qb7D1xw28Co-unsplash.txt
# kieran-white-NKN25UfGfkQ-unsplash.txt
# pauline-loroy-U3aF7hgUSrk-unsplash.txt
# peri-stojnic-5Vr_RVPfbMI-unsplash.txt
#
# Estrutura do dataset de teste:
# /content/test_dataset:
# train
#
# /content/test_dataset/train:
# Imagens  Imagens.cache	labels
#
# /content/test_dataset/train/Imagens:
# christopher-burns-ZrfnOyYUfi4-unsplash.jpg
# justin-veenema-NH1d0xX6Ldk-unsplash.jpg
# kirill-petropavlov-AYF1NkngJxs-unsplash.jpg
# lloyd-dirks-4spc49IbnpQ-unsplash.jpg
# lucas-t-wb6dyvkqpyo-unsplash.jpg
#
# /content/test_dataset/train/labels:
# christopher-burns-ZrfnOyYUfi4-unsplash.txt
# justin-veenema-NH1d0xX6Ldk-unsplash.txt
# kirill-petropavlov-AYF1NkngJxs-unsplash.txt
# lloyd-dirks-4spc49IbnpQ-unsplash.txt
# lucas-t-wb6dyvkqpyo-unsplash.txt
#
# Configurando modelo CNN...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 141, 141, 16)   │         4,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 70, 70, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 66, 66, 32)     │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 33, 33, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 31, 31, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 14400)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,879,730 (7.17 MB)
#  Trainable params: 1,879,730 (7.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Found 64 images belonging to 2 classes.
# Found 8 images belonging to 2 classes.
#
# Treinando a CNN...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 55s 14s/step - accuracy: 0.5333 - loss: 0.6618 - val_accuracy: 1.0000 - val_loss: 0.3777
# Epoch 2/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 9s/step - accuracy: 1.0000 - loss: 0.2480 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 3/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.9802e-08
# Epoch 4/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 41s 8s/step - accuracy: 1.0000 - loss: 1.3908e-08 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 35s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 34s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 12/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 32s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 34s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 41s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 15/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 34s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 16/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 32s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 17/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 34s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 18/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 35s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 19/30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 35s 9s/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 20/30
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 15s 8s/step - accuracy: 1.0000 - loss: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3292633698.py in <cell line: 0>()
#     205 # Treinar a CNN
#     206 print("\nTreinando a CNN...")
# --> 207 history = hand_model.fit(
#     208     train_generator,
#     209     epochs=30,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
